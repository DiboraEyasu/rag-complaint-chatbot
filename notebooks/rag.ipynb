# %% [markdown]
# ### Building the RAG Core Logic and Evaluation

# %%
import pandas as pd 
import sys
sys.path.append("..")

# %% [markdown]
# ##### Load the Pipeline

# %%
from src.rag import RAGPipeline

rag = RAGPipeline(
    index_path="../vectorstore/faiss_index.bin",
    metadata_path="../vectorstore/faiss_metadata.csv"
)
# Out:
# Device set to use cpu

# %%
question = "What are common complaints about credit cards?"

answer, sources = rag.answer(question)

print("Answer:\n", answer)
sources.head(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 question = "What are common complaints about credit cards?"
# ----> 3 answer, sources = rag.answer(question)
#       5 print("Answer:\n", answer)
#       6 sources.head(2)
#
# File c:\Users\UserK\rag-complaint-chatbot\notebooks\..\src\rag.py:63, in RAGPipeline.answer(self, question, k, max_new_tokens, temperature)
#      59 """
#      60 Retrieve context and generate an answer using FLAN-T5
#      61 """
#      62 # Retrieve top-k relevant chunks
# ---> 63 retrieved = self.retrieve(question, k)
#      65 # Concatenate chunk texts
#      66 context = "\n\n".join(retrieved["chunk_text"].tolist())
#
# File c:\Users\UserK\rag-complaint-chatbot\notebooks\..\src\rag.py:35, in RAGPipeline.retrieve(self, question, k)
#      31 """
#      32 Embed the question and retrieve top-k similar chunks from FAISS
#      33 """
#      34 question_vector = self.embedder.encode([question]).astype("float32")
# ---> 35 distances, indices = self.index.search(question_vector, k)
#      36 results = self.metadata.iloc[indices[0]]
#      37 return results
#
# AttributeError: 'NoneType' object has no attribute 'search'

# %%
evaluation_questions = [
    "What issues do customers report about money transfers?",
    "Are there recurring problems with savings accounts?",
    "What are common credit card complaints?",
    "Do customers mention delays in personal loan processing?",
    "Are fees a common complaint across products?"
]
results = []

for q in evaluation_questions:
    answer, sources = rag.answer(q)

    results.append({
        "Question": q,
        "Generated Answer": answer,
        "Retrieved Source": sources.iloc[0]["chunk_text"][:200],
        "Quality Score (1-5)": "",  # fill manually
        "Comments": ""
    })

evaluation_df = pd.DataFrame(results)
evaluation_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 11
#       8 results = []
#      10 for q in evaluation_questions:
# ---> 11     answer, sources = rag.answer(q)
#      13     results.append({
#      14         "Question": q,
#      15         "Generated Answer": answer,
#    (...)     18         "Comments": ""
#      19     })
#      21 evaluation_df = pd.DataFrame(results)
#
# File c:\Users\UserK\rag-complaint-chatbot\notebooks\..\src\rag.py:63, in RAGPipeline.answer(self, question, k, max_new_tokens, temperature)
#      59 """
#      60 Retrieve context and generate an answer using FLAN-T5
#      61 """
#      62 # Retrieve top-k relevant chunks
# ---> 63 retrieved = self.retrieve(question, k)
#      65 # Concatenate chunk texts
#      66 context = "\n\n".join(retrieved["chunk_text"].tolist())
#
# File c:\Users\UserK\rag-complaint-chatbot\notebooks\..\src\rag.py:35, in RAGPipeline.retrieve(self, question, k)
#      31 """
#      32 Embed the question and retrieve top-k similar chunks from FAISS
#      33 """
#      34 question_vector = self.embedder.encode([question]).astype("float32")
# ---> 35 distances, indices = self.index.search(question_vector, k)
#      36 results = self.metadata.iloc[indices[0]]
#      37 return results
#
# AttributeError: 'NoneType' object has no attribute 'search'
